# %% [markdown]
# ---
# title: "Clear docker cache"
# execute:
#   enabled: false
#   freeze: true
# date: "8/16/2024"
# categories: [docker]
# ---

# %% [markdown]
# A reminder on how to clear docker cache.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ##### Check diskspace used by Docker
# `docker system df`
#
# ##### Remove Build Cache
# `docker builder prune`
